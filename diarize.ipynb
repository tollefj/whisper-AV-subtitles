# %%
import numpy as np
import ffmpeg

SAMPLE_RATE = 16000
input_file = "store/audio.mp3"

try:
    out, _ = (
        ffmpeg.input(input_file)
        .output("-", format="s16le", acodec="pcm_s16le", ac=1, ar=str(SAMPLE_RATE))
        .run(capture_stdout=True, capture_stderr=True)
    )
except ffmpeg.Error as e:
    print("stdout:", e.stdout.decode("utf8"))
    print("stderr:", e.stderr.decode("utf8"))
    raise e
buffer = np.frombuffer(out, np.int16).flatten().astype(np.float32) / 32768.0
length_in_seconds = len(buffer) / SAMPLE_RATE

# %%
from whisperx import DiarizationPipeline, assign_word_speakers
import yaml
secrets = yaml.safe_load(open("secrets.yml"))

diarize_model = DiarizationPipeline(
    use_auth_token=secrets["HF"], device="cuda"
)
diarize_segments = diarize_model(
    buffer, min_speakers=None, max_speakers=None
)
diarize_segments = diarize_model(buffer)
result = assign_word_speakers(diarize_segments, result)

# %%
# instantiate the pipeline
from pyannote.audio.pipelines.utils.hook import ProgressHook
from pyannote.audio import Pipeline
import yaml
import torch

secrets = yaml.safe_load(open('secrets.yml'))
pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token=secrets["HF"])
pipeline.to(torch.device("cuda"))

# run the pipeline on an audio file
# diarization = pipeline("store/audio.mp3")
with ProgressHook() as hook:
    diarization = pipeline("store/audio.mp3", hook=hook)
# Out:
# /home/tollef/.local/lib/python3.10/site-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /home/tollef/.local/lib/python3.10/site-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# Output()

# %%
from utils.whisper_util import transcribe
transcription = transcribe(audio_path="store/audio.mp3", align=True)
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.1+cu118. Bad things might happen unless you revert torch to 1.x.
# 1. Transcribing...
# Detected language: en (1.00) in first 30s of audio...
# 2. Aligning...
# Detected audio with length 232.5710625 seconds

# %%
transcription["segments"]
# Out:
# [{'start': 0.249,
#   'end': 5.173,
#   'text': ' Just one year after launch, Chat GPT has well over 100 million daily active users.',
#   'words': [{'word': 'Just', 'start': 0.249, 'end': 0.449, 'score': 0.698},
#    {'word': 'one', 'start': 0.609, 'end': 0.709, 'score': 0.685},
#    {'word': 'year', 'start': 0.75, 'end': 0.91, 'score': 0.804},
#    {'word': 'after', 'start': 0.99, 'end': 1.21, 'score': 0.728},
#    {'word': 'launch,', 'start': 1.27, 'end': 1.59, 'score': 0.942},
#    {'word': 'Chat', 'start': 1.67, 'end': 1.85, 'score': 0.891},
#    {'word': 'GPT', 'start': 1.87, 'end': 2.371, 'score': 0.761},
#    {'word': 'has', 'start': 2.411, 'end': 2.571, 'score': 0.822},
#    {'word': 'well', 'start': 2.631, 'end': 2.811, 'score': 0.875},
#    {'word': 'over', 'start': 2.911, 'end': 3.111, 'score': 0.838},
#    {'word': '100'},
#    {'word': 'million', 'start': 3.712, 'end': 4.052, 'score': 0.879},
#    {'word': 'daily', 'start': 4.092, 'end': 4.372, 'score': 0.863},
#    {'word': 'active', 'start': 4.472, 'end': 4.712, 'score': 0.862},
#    {'word': 'users.', 'start': 4.832, 'end': 5.173, 'score': 0.821}]},
#  {'start': 5.353,
#   'end': 11.917,
#   'text': 'And next week, OpenAI is opening the floodgates, allowing developers to profit on their platform by selling custom GPT agents.',
#   'words': [{'word': 'And', 'start': 5.353, 'end': 5.453, 'score': 0.795},
#    {'word': 'next', 'start': 5.513, 'end': 5.733, 'score': 0.69},
#    {'word': 'week,', 'start': 5.793, 'end': 5.973, 'score': 0.833},
#    {'word': 'OpenAI', 'start': 6.053, 'end': 6.534, 'score': 0.851},
#    {'word': 'is', 'start': 6.594, 'end': 6.674, 'score': 0.506},
#    {'word': 'opening', 'start': 6.774, 'end': 7.034, 'score': 0.897},
#    {'word': 'the', 'start': 7.054, 'end': 7.134, 'score': 0.834},
#    {'word': 'floodgates,', 'start': 7.154, 'end': 7.694, 'score': 0.914},
#    {'word': 'allowing', 'start': 7.794, 'end': 8.135, 'score': 0.83},
#    {'word': 'developers', 'start': 8.155, 'end': 8.655, 'score': 0.751},
#    {'word': 'to', 'start': 8.695, 'end': 8.835, 'score': 0.868},
#    {'word': 'profit', 'start': 8.895, 'end': 9.195, 'score': 0.895},
#    {'word': 'on', 'start': 9.256, 'end': 9.316, 'score': 0.75},
#    {'word': 'their', 'start': 9.336, 'end': 9.456, 'score': 0.969},
#    {'word': 'platform', 'start': 9.496, 'end': 10.016, 'score': 0.81},
#    {'word': 'by', 'start': 10.076, 'end': 10.216, 'score': 0.826},
#    {'word': 'selling', 'start': 10.256, 'end': 10.576, 'score': 0.807},
#    {'word': 'custom', 'start': 10.656, 'end': 11.017, 'score': 0.827},
#    {'word': 'GPT', 'start': 11.037, 'end': 11.477, 'score': 0.905},
#    {'word': 'agents.', 'start': 11.557, 'end': 11.917, 'score': 0.834}]},
#  {'start': 11.997,
#   'end': 18.802,
#   'text': "All you have to do is convince 1% of the user base to pay you $1 per month for your custom agent, and you'll be a deck of millionaire by the end of the year.",
#   'words': [{'word': 'All', 'start': 11.997, 'end': 12.118, 'score': 0.806},
#    {'word': 'you', 'start': 12.138, 'end': 12.258, 'score': 0.814},
#    {'word': 'have', 'start': 12.278, 'end': 12.378, 'score': 0.936},
#    {'word': 'to', 'start': 12.398, 'end': 12.458, 'score': 0.752},
#    {'word': 'do', 'start': 12.498, 'end': 12.618, 'score': 0.858},
#    {'word': 'is', 'start': 12.698, 'end': 12.758, 'score': 0.736},
#    {'word': 'convince', 'start': 12.798, 'end': 13.579, 'score': 0.768},
#    {'word': '1%'},
#    {'word': 'of', 'start': 13.619, 'end': 13.679, 'score': 0.75},
#    {'word': 'the', 'start': 13.699, 'end': 13.759, 'score': 0.998},
#    {'word': 'user', 'start': 13.859, 'end': 14.079, 'score': 0.628},
#    {'word': 'base', 'start': 14.099, 'end': 14.339, 'score': 0.93},
#    {'word': 'to', 'start': 14.379, 'end': 14.459, 'score': 0.781},
#    {'word': 'pay', 'start': 14.499, 'end': 14.639, 'score': 0.8},
#    {'word': 'you', 'start': 14.659, 'end': 14.799, 'score': 0.792},
#    {'word': '$1'},
#    {'word': 'per', 'start': 15.34, 'end': 15.48, 'score': 0.812},
#    {'word': 'month', 'start': 15.52, 'end': 15.72, 'score': 0.814},
#    {'word': 'for', 'start': 15.76, 'end': 15.86, 'score': 0.963},
#    {'word': 'your', 'start': 15.88, 'end': 16.02, 'score': 0.732},
#    {'word': 'custom', 'start': 16.06, 'end': 16.381, 'score': 0.872},
#    {'word': 'agent,', 'start': 16.481, 'end': 16.781, 'score': 0.905},
#    {'word': 'and', 'start': 16.841, 'end': 16.921, 'score': 0.836},
#    {'word': "you'll", 'start': 16.941, 'end': 17.121, 'score': 0.851},
#    {'word': 'be', 'start': 17.141, 'end': 17.221, 'score': 0.674},
#    {'word': 'a', 'start': 17.241, 'end': 17.281, 'score': 0.616},
#    {'word': 'deck', 'start': 17.321, 'end': 17.481, 'score': 0.858},
#    {'word': 'of', 'start': 17.521, 'end': 17.561, 'score': 0.007},
#    {'word': 'millionaire', 'start': 17.601, 'end': 18.022, 'score': 0.755},
#    {'word': 'by', 'start': 18.042, 'end': 18.142, 'score': 0.754},
#    {'word': 'the', 'start': 18.182, 'end': 18.262, 'score': 0.834},
#    {'word': 'end', 'start': 18.302, 'end': 18.382, 'score': 0.955},
#    {'word': 'of', 'start': 18.402, 'end': 18.462, 'score': 0.748},
#    {'word': 'the', 'start': 18.482, 'end': 18.562, 'score': 0.833},
#    {'word': 'year.', 'start': 18.602, 'end': 18.802, 'score': 0.794}]},
#  {'start': 18.902,
#   'end': 23.425,
#   'text': "By the end of today's video, you'll know how to get rich from this once-in-a-lifetime shovelware opportunity.",
#   'words': [{'word': 'By', 'start': 18.902, 'end': 19.002, 'score': 0.825},
#    {'word': 'the', 'start': 19.022, 'end': 19.122, 'score': 0.668},
#    {'word': 'end', 'start': 19.183, 'end': 19.283, 'score': 0.824},
#    {'word': 'of', 'start': 19.323, 'end': 19.383, 'score': 0.749},
#    {'word': "today's", 'start': 19.403, 'end': 19.683, 'score': 0.729},
#    {'word': 'video,', 'start': 19.703, 'end': 20.143, 'score': 0.853},
#    {'word': "you'll", 'start': 20.203, 'end': 20.363, 'score': 0.91},
#    {'word': 'know', 'start': 20.383, 'end': 20.483, 'score': 0.887},
#    {'word': 'how', 'start': 20.523, 'end': 20.604, 'score': 0.839},
#    {'word': 'to', 'start': 20.624, 'end': 20.664, 'score': 1.0},
#    {'word': 'get', 'start': 20.704, 'end': 20.824, 'score': 0.633},
#    {'word': 'rich', 'start': 20.924, 'end': 21.144, 'score': 0.916},
#    {'word': 'from', 'start': 21.164, 'end': 21.284, 'score': 0.795},
#    {'word': 'this', 'start': 21.304, 'end': 21.444, 'score': 0.717},
#    {'word': 'once-in-a-lifetime',
#     'start': 21.564,
#     'end': 22.365,
#     'score': 0.789},
#    {'word': 'shovelware', 'start': 22.405, 'end': 22.845, 'score': 0.633},
#    {'word': 'opportunity.', 'start': 22.885, 'end': 23.425, 'score': 0.921}]},
#  {'start': 23.526,
#   'end': 26.848,
#   'text': 'It is January 5th, 2024, and you are watching the code report.',
#   'words': [{'word': 'It', 'start': 23.526, 'end': 23.606, 'score': 0.842},
#    {'word': 'is', 'start': 23.646, 'end': 23.726, 'score': 0.926},
#    {'word': 'January', 'start': 23.786, 'end': 24.206, 'score': 0.663},
#    {'word': '5th,', 'start': 24.406, 'end': 24.486, 'score': 0.678},
#    {'word': '2024,'},
#    {'word': 'and', 'start': 24.606, 'end': 24.726, 'score': 0.437},
#    {'word': 'you', 'start': 24.947, 'end': 25.387, 'score': 0.69},
#    {'word': 'are', 'start': 25.547, 'end': 25.907, 'score': 0.644},
#    {'word': 'watching', 'start': 25.947, 'end': 26.207, 'score': 0.771},
#    {'word': 'the', 'start': 26.247, 'end': 26.328, 'score': 0.885},
#    {'word': 'code', 'start': 26.348, 'end': 26.568, 'score': 0.643},
#    {'word': 'report.', 'start': 26.588, 'end': 26.848, 'score': 0.599}]},
#  {'start': 26.988,
#   'end': 29.608,
#   'text': ' Building a custom GPT agent is way too easy.',
#   'words': [{'word': 'Building',
#     'start': 26.988,
#     'end': 27.268,
#     'score': 0.82},
#    {'word': 'a', 'start': 27.308, 'end': 27.368, 'score': 0.678},
#    {'word': 'custom', 'start': 27.408, 'end': 27.748, 'score': 0.839},
#    {'word': 'GPT', 'start': 27.768, 'end': 28.168, 'score': 0.789},
#    {'word': 'agent', 'start': 28.268, 'end': 28.608, 'score': 0.828},
#    {'word': 'is', 'start': 28.748, 'end': 28.868, 'score': 0.832},
#    {'word': 'way', 'start': 28.948, 'end': 29.108, 'score': 0.804},
#    {'word': 'too', 'start': 29.128, 'end': 29.268, 'score': 0.838},
#    {'word': 'easy.', 'start': 29.348, 'end': 29.608, 'score': 0.932}]},
#  {'start': 29.688,
#   'end': 43.391,
#   'text': 'Literally all you do is go down to myGPTs, create a new agent, give it some custom instructions and conversation starters, and maybe upload some files with some custom data, release it on the store next week, then slap the hood and tell people how this bad boy can solve all their problems.',
#   'words': [{'word': 'Literally',
#     'start': 29.688,
#     'end': 30.049,
#     'score': 0.868},
#    {'word': 'all', 'start': 30.129, 'end': 30.229, 'score': 0.895},
#    {'word': 'you', 'start': 30.269, 'end': 30.369, 'score': 0.995},
#    {'word': 'do', 'start': 30.409, 'end': 30.649, 'score': 0.776},
#    {'word': 'is', 'start': 30.769, 'end': 30.849, 'score': 0.904},
#    {'word': 'go', 'start': 30.889, 'end': 31.009, 'score': 0.867},
#    {'word': 'down', 'start': 31.029, 'end': 31.189, 'score': 0.909},
#    {'word': 'to', 'start': 31.229, 'end': 31.309, 'score': 0.926},
#    {'word': 'myGPTs,', 'start': 31.349, 'end': 32.249, 'score': 0.789},
#    {'word': 'create', 'start': 32.329, 'end': 32.489, 'score': 0.5},
#    {'word': 'a', 'start': 32.509, 'end': 32.569, 'score': 0.665},
#    {'word': 'new', 'start': 32.589, 'end': 32.689, 'score': 0.834},
#    {'word': 'agent,', 'start': 32.809, 'end': 33.189, 'score': 0.828},
#    {'word': 'give', 'start': 33.329, 'end': 33.449, 'score': 0.847},
#    {'word': 'it', 'start': 33.489, 'end': 33.549, 'score': 0.75},
#    {'word': 'some', 'start': 33.569, 'end': 33.689, 'score': 0.881},
#    {'word': 'custom', 'start': 33.729, 'end': 34.049, 'score': 0.863},
#    {'word': 'instructions', 'start': 34.089, 'end': 34.689, 'score': 0.878},
#    {'word': 'and', 'start': 34.749, 'end': 34.849, 'score': 0.706},
#    {'word': 'conversation', 'start': 34.909, 'end': 35.509, 'score': 0.906},
#    {'word': 'starters,', 'start': 35.529, 'end': 36.01, 'score': 0.789},
#    {'word': 'and', 'start': 36.19, 'end': 36.27, 'score': 0.891},
#    {'word': 'maybe', 'start': 36.31, 'end': 36.53, 'score': 0.889},
#    {'word': 'upload', 'start': 36.61, 'end': 36.87, 'score': 0.679},
#    {'word': 'some', 'start': 36.89, 'end': 37.01, 'score': 0.176},
#    {'word': 'files', 'start': 37.05, 'end': 37.37, 'score': 0.77},
#    {'word': 'with', 'start': 37.41, 'end': 37.51, 'score': 0.998},
#    {'word': 'some', 'start': 37.55, 'end': 37.65, 'score': 0.891},
#    {'word': 'custom', 'start': 37.69, 'end': 38.03, 'score': 0.85},
#    {'word': 'data,', 'start': 38.05, 'end': 38.37, 'score': 0.872},
#    {'word': 'release', 'start': 38.45, 'end': 38.71, 'score': 0.826},
#    {'word': 'it', 'start': 38.75, 'end': 38.81, 'score': 0.77},
#    {'word': 'on', 'start': 38.85, 'end': 38.89, 'score': 0.999},
#    {'word': 'the', 'start': 38.93, 'end': 38.99, 'score': 0.996},
#    {'word': 'store', 'start': 39.01, 'end': 39.21, 'score': 0.843},
#    {'word': 'next', 'start': 39.25, 'end': 39.43, 'score': 0.748},
#    {'word': 'week,', 'start': 39.51, 'end': 39.75, 'score': 0.728},
#    {'word': 'then', 'start': 39.87, 'end': 40.03, 'score': 0.966},
#    {'word': 'slap', 'start': 40.07, 'end': 40.35, 'score': 0.912},
#    {'word': 'the', 'start': 40.39, 'end': 40.45, 'score': 0.999},
#    {'word': 'hood', 'start': 40.49, 'end': 40.77, 'score': 0.818},
#    {'word': 'and', 'start': 40.87, 'end': 40.95, 'score': 0.876},
#    {'word': 'tell', 'start': 40.97, 'end': 41.15, 'score': 0.81},
#    {'word': 'people', 'start': 41.17, 'end': 41.43, 'score': 0.911},
#    {'word': 'how', 'start': 41.47, 'end': 41.61, 'score': 0.923},
#    {'word': 'this', 'start': 41.63, 'end': 41.791, 'score': 0.643},
#    {'word': 'bad', 'start': 41.831, 'end': 42.051, 'score': 0.982},
#    {'word': 'boy', 'start': 42.091, 'end': 42.251, 'score': 0.923},
#    {'word': 'can', 'start': 42.291, 'end': 42.411, 'score': 0.945},
#    {'word': 'solve', 'start': 42.451, 'end': 42.651, 'score': 0.821},
#    {'word': 'all', 'start': 42.671, 'end': 42.771, 'score': 0.89},
#    {'word': 'their', 'start': 42.791, 'end': 42.931, 'score': 0.882},
#    {'word': 'problems.', 'start': 42.951, 'end': 43.391, 'score': 0.803}]},
#  {'start': 43.431,
#   'end': 48.952,
#   'text': 'The barrier to entry is extremely low, and that means the GPT store will likely be filled with crapware by the end of next week.',
#   'words': [{'word': 'The', 'start': 43.431, 'end': 43.531, 'score': 0.928},
#    {'word': 'barrier', 'start': 43.551, 'end': 43.891, 'score': 0.754},
#    {'word': 'to', 'start': 43.911, 'end': 43.991, 'score': 0.667},
#    {'word': 'entry', 'start': 44.071, 'end': 44.331, 'score': 0.874},
#    {'word': 'is', 'start': 44.371, 'end': 44.451, 'score': 0.722},
#    {'word': 'extremely', 'start': 44.511, 'end': 44.951, 'score': 0.771},
#    {'word': 'low,', 'start': 45.031, 'end': 45.271, 'score': 0.909},
#    {'word': 'and', 'start': 45.351, 'end': 45.431, 'score': 0.875},
#    {'word': 'that', 'start': 45.451, 'end': 45.571, 'score': 0.875},
#    {'word': 'means', 'start': 45.591, 'end': 45.771, 'score': 0.813},
#    {'word': 'the', 'start': 45.811, 'end': 45.891, 'score': 0.832},
#    {'word': 'GPT', 'start': 45.911, 'end': 46.331, 'score': 0.863},
#    {'word': 'store', 'start': 46.371, 'end': 46.591, 'score': 0.812},
#    {'word': 'will', 'start': 46.611, 'end': 46.731, 'score': 0.919},
#    {'word': 'likely', 'start': 46.751, 'end': 46.991, 'score': 0.777},
#    {'word': 'be', 'start': 47.031, 'end': 47.111, 'score': 0.55},
#    {'word': 'filled', 'start': 47.151, 'end': 47.331, 'score': 0.916},
#    {'word': 'with', 'start': 47.351, 'end': 47.451, 'score': 0.876},
#    {'word': 'crapware', 'start': 47.491, 'end': 47.912, 'score': 0.783},
#    {'word': 'by', 'start': 47.932, 'end': 48.032, 'score': 0.896},
#    {'word': 'the', 'start': 48.072, 'end': 48.172, 'score': 0.831},
#    {'word': 'end', 'start': 48.232, 'end': 48.332, 'score': 0.845},
#    {'word': 'of', 'start': 48.372, 'end': 48.432, 'score': 0.742},
#    {'word': 'next', 'start': 48.492, 'end': 48.672, 'score': 0.751},
#    {'word': 'week.', 'start': 48.732, 'end': 48.952, 'score': 0.773}]},
#  {'start': 49.132,
#   'end': 55.273,
#   'text': "But it may not be the only store in town for long, who incidentally screenshots for Google's bar advanced were just leaked hours ago.",
#   'words': [{'word': 'But', 'start': 49.132, 'end': 49.252, 'score': 0.856},
#    {'word': 'it', 'start': 49.272, 'end': 49.332, 'score': 0.748},
#    {'word': 'may', 'start': 49.352, 'end': 49.472, 'score': 0.779},
#    {'word': 'not', 'start': 49.492, 'end': 49.592, 'score': 1.0},
#    {'word': 'be', 'start': 49.632, 'end': 49.732, 'score': 0.806},
#    {'word': 'the', 'start': 49.752, 'end': 49.852, 'score': 0.663},
#    {'word': 'only', 'start': 49.912, 'end': 50.092, 'score': 0.748},
#    {'word': 'store', 'start': 50.132, 'end': 50.332, 'score': 0.805},
#    {'word': 'in', 'start': 50.372, 'end': 50.432, 'score': 0.996},
#    {'word': 'town', 'start': 50.472, 'end': 50.712, 'score': 0.962},
#    {'word': 'for', 'start': 50.752, 'end': 50.872, 'score': 0.896},
#    {'word': 'long,', 'start': 50.912, 'end': 51.192, 'score': 0.846},
#    {'word': 'who', 'start': 51.232, 'end': 51.312, 'score': 0.98},
#    {'word': 'incidentally', 'start': 51.352, 'end': 51.932, 'score': 0.847},
#    {'word': 'screenshots', 'start': 52.032, 'end': 52.572, 'score': 0.89},
#    {'word': 'for', 'start': 52.612, 'end': 52.812, 'score': 0.773},
#    {'word': "Google's", 'start': 52.872, 'end': 53.252, 'score': 0.674},
#    {'word': 'bar', 'start': 53.332, 'end': 53.593, 'score': 0.839},
#    {'word': 'advanced', 'start': 53.633, 'end': 54.053, 'score': 0.946},
#    {'word': 'were', 'start': 54.093, 'end': 54.233, 'score': 0.881},
#    {'word': 'just', 'start': 54.273, 'end': 54.413, 'score': 0.769},
#    {'word': 'leaked', 'start': 54.473, 'end': 54.693, 'score': 0.881},
#    {'word': 'hours', 'start': 54.773, 'end': 55.053, 'score': 0.803},
#    {'word': 'ago.', 'start': 55.093, 'end': 55.273, 'score': 0.898}]},
#  {'start': 55.373,
#   'end': 56.453,
#   'text': 'It looks like barred may have its',
#   'words': [{'word': 'It', 'start': 55.373, 'end': 55.433, 'score': 0.754},
#    {'word': 'looks', 'start': 55.453, 'end': 55.593, 'score': 0.863},
#    {'word': 'like', 'start': 55.633, 'end': 55.793, 'score': 0.76},
#    {'word': 'barred', 'start': 55.853, 'end': 56.073, 'score': 0.803},
#    {'word': 'may', 'start': 56.093, 'end': 56.193, 'score': 0.815},
#    {'word': 'have', 'start': 56.233, 'end': 56.333, 'score': 0.921},
#    {'word': 'its', 'start': 56.393, 'end': 56.453, 'score': 0.986}]},
#  {'start': 56.613,
#   'end': 60.816,
#   'text': ' own paid tier based on Gemini Ultra in the future, along with a marketplace for developers.',
#   'words': [{'word': 'own', 'start': 56.613, 'end': 56.753, 'score': 0.773},
#    {'word': 'paid', 'start': 56.773, 'end': 56.993, 'score': 0.77},
#    {'word': 'tier', 'start': 57.013, 'end': 57.194, 'score': 0.328},
#    {'word': 'based', 'start': 57.234, 'end': 57.454, 'score': 0.85},
#    {'word': 'on', 'start': 57.514, 'end': 57.594, 'score': 0.836},
#    {'word': 'Gemini', 'start': 57.634, 'end': 57.994, 'score': 0.683},
#    {'word': 'Ultra', 'start': 58.094, 'end': 58.354, 'score': 0.64},
#    {'word': 'in', 'start': 58.374, 'end': 58.454, 'score': 0.658},
#    {'word': 'the', 'start': 58.474, 'end': 58.535, 'score': 0.994},
#    {'word': 'future,', 'start': 58.575, 'end': 58.915, 'score': 0.852},
#    {'word': 'along', 'start': 58.995, 'end': 59.195, 'score': 0.732},
#    {'word': 'with', 'start': 59.215, 'end': 59.315, 'score': 0.874},
#    {'word': 'a', 'start': 59.375, 'end': 59.435, 'score': 0.686},
#    {'word': 'marketplace', 'start': 59.495, 'end': 60.016, 'score': 0.883},
#    {'word': 'for', 'start': 60.056, 'end': 60.176, 'score': 0.779},
#    {'word': 'developers.', 'start': 60.256, 'end': 60.816, 'score': 0.758}]},
#  {'start': 60.876,
#   'end': 62.517,
#   'text': "But that's pure speculation at this point.",
#   'words': [{'word': 'But', 'start': 60.876, 'end': 61.016, 'score': 0.814},
#    {'word': "that's", 'start': 61.056, 'end': 61.257, 'score': 0.896},
#    {'word': 'pure', 'start': 61.297, 'end': 61.457, 'score': 0.859},
#    {'word': 'speculation', 'start': 61.497, 'end': 62.017, 'score': 0.86},
#    {'word': 'at', 'start': 62.057, 'end': 62.097, 'score': 0.992},
#    {'word': 'this', 'start': 62.117, 'end': 62.257, 'score': 0.786},
#    {'word': 'point.', 'start': 62.317, 'end': 62.517, 'score': 0.779}]},
#  {'start': 62.578,
#   'end': 66.42,
#   'text': 'Now, another big question mark is what will the revenue split be on the Chatchee BT store?',
#   'words': [{'word': 'Now,', 'start': 62.578, 'end': 62.718, 'score': 0.902},
#    {'word': 'another', 'start': 62.838, 'end': 63.038, 'score': 0.858},
#    {'word': 'big', 'start': 63.078, 'end': 63.198, 'score': 0.96},
#    {'word': 'question', 'start': 63.218, 'end': 63.558, 'score': 0.806},
#    {'word': 'mark', 'start': 63.578, 'end': 63.818, 'score': 0.776},
#    {'word': 'is', 'start': 63.898, 'end': 63.979, 'score': 0.689},
#    {'word': 'what', 'start': 64.019, 'end': 64.139, 'score': 0.755},
#    {'word': 'will', 'start': 64.159, 'end': 64.279, 'score': 0.959},
#    {'word': 'the', 'start': 64.299, 'end': 64.379, 'score': 0.831},
#    {'word': 'revenue', 'start': 64.419, 'end': 64.739, 'score': 0.81},
#    {'word': 'split', 'start': 64.759, 'end': 64.999, 'score': 0.846},
#    {'word': 'be', 'start': 65.039, 'end': 65.219, 'score': 0.89},
#    {'word': 'on', 'start': 65.28, 'end': 65.36, 'score': 0.9},
#    {'word': 'the', 'start': 65.38, 'end': 65.46, 'score': 0.806},
#    {'word': 'Chatchee', 'start': 65.48, 'end': 65.8, 'score': 0.706},
#    {'word': 'BT', 'start': 65.82, 'end': 66.1, 'score': 0.835},
#    {'word': 'store?', 'start': 66.14, 'end': 66.42, 'score': 0.738}]},
#  {'start': 66.46,
#   'end': 69.503,
#   'text': 'Will it be $70.30 like Apple, or will it be much lower than that?',
#   'words': [{'word': 'Will', 'start': 66.46, 'end': 66.601, 'score': 0.792},
#    {'word': 'it', 'start': 66.641, 'end': 66.681, 'score': 0.994},
#    {'word': 'be', 'start': 66.721, 'end': 66.821, 'score': 0.83},
#    {'word': '$70.30'},
#    {'word': 'like', 'start': 67.501, 'end': 67.641, 'score': 0.727},
#    {'word': 'Apple,', 'start': 67.761, 'end': 68.062, 'score': 0.752},
#    {'word': 'or', 'start': 68.202, 'end': 68.282, 'score': 0.724},
#    {'word': 'will', 'start': 68.302, 'end': 68.422, 'score': 0.887},
#    {'word': 'it', 'start': 68.462, 'end': 68.502, 'score': 0.988},
#    {'word': 'be', 'start': 68.542, 'end': 68.662, 'score': 0.744},
#    {'word': 'much', 'start': 68.702, 'end': 68.862, 'score': 0.831},
#    {'word': 'lower', 'start': 68.942, 'end': 69.122, 'score': 0.822},
#    {'word': 'than', 'start': 69.162, 'end': 69.262, 'score': 0.944},
#    {'word': 'that?', 'start': 69.303, 'end': 69.503, 'score': 0.566}]},
#  {'start': 69.563,
#   'end': 71.684,
#   'text': 'Because OpenAI is kind of doing most of the work here.',
#   'words': [{'word': 'Because',
#     'start': 69.563,
#     'end': 69.863,
#     'score': 0.891},
#    {'word': 'OpenAI', 'start': 69.883, 'end': 70.243, 'score': 0.687},
#    {'word': 'is', 'start': 70.303, 'end': 70.443, 'score': 0.425},
#    {'word': 'kind', 'start': 70.483, 'end': 70.603, 'score': 0.89},
#    {'word': 'of', 'start': 70.644, 'end': 70.684, 'score': 0.998},
#    {'word': 'doing', 'start': 70.744, 'end': 70.944, 'score': 0.882},
#    {'word': 'most', 'start': 70.964, 'end': 71.124, 'score': 0.737},
#    {'word': 'of', 'start': 71.164, 'end': 71.204, 'score': 0.99},
#    {'word': 'the', 'start': 71.224, 'end': 71.304, 'score': 0.815},
#    {'word': 'work', 'start': 71.344, 'end': 71.504, 'score': 0.801},
#    {'word': 'here.', 'start': 71.544, 'end': 71.684, 'score': 0.868}]},
#  {'start': 71.784,
#   'end': 76.928,
#   'text': "In any case, there'll be some kind of leaderboard, so if you actually create something useful, if there's a good chance you'll make a lot of money.",
#   'words': [{'word': 'In', 'start': 71.784, 'end': 71.824, 'score': 0.994},
#    {'word': 'any', 'start': 71.884, 'end': 71.984, 'score': 0.839},
#    {'word': 'case,', 'start': 72.025, 'end': 72.265, 'score': 0.766},
#    {'word': "there'll", 'start': 72.305, 'end': 72.525, 'score': 0.944},
#    {'word': 'be', 'start': 72.545, 'end': 72.605, 'score': 0.976},
#    {'word': 'some', 'start': 72.645, 'end': 72.785, 'score': 0.71},
#    {'word': 'kind', 'start': 72.805, 'end': 72.945, 'score': 0.788},
#    {'word': 'of', 'start': 72.965, 'end': 73.025, 'score': 0.749},
#    {'word': 'leaderboard,', 'start': 73.085, 'end': 73.606, 'score': 0.793},
#    {'word': 'so', 'start': 73.646, 'end': 73.766, 'score': 0.096},
#    {'word': 'if', 'start': 73.786, 'end': 73.826, 'score': 0.993},
#    {'word': 'you', 'start': 73.846, 'end': 73.966, 'score': 0.928},
#    {'word': 'actually', 'start': 74.006, 'end': 74.286, 'score': 0.74},
#    {'word': 'create', 'start': 74.326, 'end': 74.526, 'score': 0.844},
#    {'word': 'something', 'start': 74.566, 'end': 74.827, 'score': 0.951},
#    {'word': 'useful,', 'start': 74.947, 'end': 75.247, 'score': 0.86},
#    {'word': 'if', 'start': 75.267, 'end': 75.427, 'score': 0.46},
#    {'word': "there's", 'start': 75.447, 'end': 75.607, 'score': 0.899},
#    {'word': 'a', 'start': 75.627, 'end': 75.667, 'score': 0.485},
#    {'word': 'good', 'start': 75.687, 'end': 75.807, 'score': 0.874},
#    {'word': 'chance', 'start': 75.847, 'end': 76.068, 'score': 0.936},
#    {'word': "you'll", 'start': 76.088, 'end': 76.248, 'score': 0.901},
#    {'word': 'make', 'start': 76.268, 'end': 76.368, 'score': 0.876},
#    {'word': 'a', 'start': 76.408, 'end': 76.428, 'score': 0.996},
#    {'word': 'lot', 'start': 76.468, 'end': 76.588, 'score': 0.674},
#    {'word': 'of', 'start': 76.608, 'end': 76.668, 'score': 0.749},
#    {'word': 'money.', 'start': 76.728, 'end': 76.928, 'score': 0.772}]},
#  {'start': 77.088,
#   'end': 79.25,
#   'text': 'Now the question becomes, what should I actually build?',
#   'words': [{'word': 'Now', 'start': 77.088, 'end': 77.208, 'score': 0.713},
#    {'word': 'the', 'start': 77.228, 'end': 77.308, 'score': 0.83},
#    {'word': 'question', 'start': 77.328, 'end': 77.629, 'score': 0.856},
#    {'word': 'becomes,', 'start': 77.669, 'end': 78.049, 'score': 0.754},
#    {'word': 'what', 'start': 78.169, 'end': 78.289, 'score': 0.949},
#    {'word': 'should', 'start': 78.309, 'end': 78.429, 'score': 0.687},
#    {'word': 'I', 'start': 78.469, 'end': 78.549, 'score': 0.828},
#    {'word': 'actually', 'start': 78.609, 'end': 78.95, 'score': 0.812},
#    {'word': 'build?', 'start': 78.99, 'end': 79.25, 'score': 0.694}]},
#  {'start': 79.37,
#   'end': 86.135,
#   'text': "There's already a bunch of agents built by OpenAI, like this one that will create a die cut sticker for you, and then provide a link where you can actually buy those stickers.",
#   'words': [{'word': "There's", 'start': 79.37, 'end': 79.53, 'score': 0.944},
#    {'word': 'already', 'start': 79.55, 'end': 79.77, 'score': 0.442},
#    {'word': 'a', 'start': 79.79, 'end': 79.83, 'score': 0.495},
#    {'word': 'bunch', 'start': 79.85, 'end': 80.01, 'score': 0.778},
#    {'word': 'of', 'start': 80.05, 'end': 80.111, 'score': 0.748},
#    {'word': 'agents', 'start': 80.191, 'end': 80.471, 'score': 0.829},
#    {'word': 'built', 'start': 80.511, 'end': 80.691, 'score': 0.739},
#    {'word': 'by', 'start': 80.711, 'end': 80.851, 'score': 0.739},
#    {'word': 'OpenAI,', 'start': 80.951, 'end': 81.572, 'score': 0.682},
#    {'word': 'like', 'start': 81.672, 'end': 81.832, 'score': 0.765},
#    {'word': 'this', 'start': 81.872, 'end': 81.992, 'score': 0.868},
#    {'word': 'one', 'start': 82.072, 'end': 82.152, 'score': 0.833},
#    {'word': 'that', 'start': 82.172, 'end': 82.252, 'score': 0.999},
#    {'word': 'will', 'start': 82.272, 'end': 82.392, 'score': 0.88},
#    {'word': 'create', 'start': 82.412, 'end': 82.592, 'score': 0.694},
#    {'word': 'a', 'start': 82.612, 'end': 82.692, 'score': 0.835},
#    {'word': 'die', 'start': 82.752, 'end': 82.953, 'score': 0.773},
#    {'word': 'cut', 'start': 82.973, 'end': 83.193, 'score': 0.892},
#    {'word': 'sticker', 'start': 83.213, 'end': 83.513, 'score': 0.899},
#    {'word': 'for', 'start': 83.533, 'end': 83.693, 'score': 0.83},
#    {'word': 'you,', 'start': 83.713, 'end': 83.853, 'score': 0.866},
#    {'word': 'and', 'start': 83.873, 'end': 84.013, 'score': 0.31},
#    {'word': 'then', 'start': 84.033, 'end': 84.134, 'score': 0.434},
#    {'word': 'provide', 'start': 84.154, 'end': 84.394, 'score': 0.798},
#    {'word': 'a', 'start': 84.414, 'end': 84.454, 'score': 0.49},
#    {'word': 'link', 'start': 84.514, 'end': 84.674, 'score': 0.92},
#    {'word': 'where', 'start': 84.694, 'end': 84.834, 'score': 0.811},
#    {'word': 'you', 'start': 84.854, 'end': 84.934, 'score': 0.833},
#    {'word': 'can', 'start': 84.954, 'end': 85.054, 'score': 0.756},
#    {'word': 'actually', 'start': 85.114, 'end': 85.434, 'score': 0.736},
#    {'word': 'buy', 'start': 85.475, 'end': 85.655, 'score': 0.713},
#    {'word': 'those', 'start': 85.695, 'end': 85.855, 'score': 0.911},
#    {'word': 'stickers.', 'start': 85.875, 'end': 86.135, 'score': 0.821}]},
#  {'start': 86.275,
#   'end': 90.737,
#   'text': " These are pretty cool, but luckily I have some banger ideas that I'm not going to build that you can have for free.",
#   'words': [{'word': 'These', 'start': 86.275, 'end': 86.415, 'score': 0.842},
#    {'word': 'are', 'start': 86.435, 'end': 86.515, 'score': 0.905},
#    {'word': 'pretty', 'start': 86.535, 'end': 86.695, 'score': 0.945},
#    {'word': 'cool,', 'start': 86.735, 'end': 87.035, 'score': 0.822},
#    {'word': 'but', 'start': 87.156, 'end': 87.276, 'score': 0.882},
#    {'word': 'luckily', 'start': 87.356, 'end': 87.656, 'score': 0.715},
#    {'word': 'I', 'start': 87.696, 'end': 87.756, 'score': 0.679},
#    {'word': 'have', 'start': 87.816, 'end': 87.956, 'score': 0.889},
#    {'word': 'some', 'start': 87.996, 'end': 88.136, 'score': 0.838},
#    {'word': 'banger', 'start': 88.176, 'end': 88.456, 'score': 0.922},
#    {'word': 'ideas', 'start': 88.516, 'end': 88.776, 'score': 0.902},
#    {'word': 'that', 'start': 88.816, 'end': 88.936, 'score': 0.871},
#    {'word': "I'm", 'start': 88.956, 'end': 89.056, 'score': 0.598},
#    {'word': 'not', 'start': 89.096, 'end': 89.217, 'score': 0.937},
#    {'word': 'going', 'start': 89.257, 'end': 89.397, 'score': 0.89},
#    {'word': 'to', 'start': 89.417, 'end': 89.477, 'score': 0.75},
#    {'word': 'build', 'start': 89.517, 'end': 89.717, 'score': 0.696},
#    {'word': 'that', 'start': 89.737, 'end': 89.837, 'score': 0.817},
#    {'word': 'you', 'start': 89.877, 'end': 89.957, 'score': 0.848},
#    {'word': 'can', 'start': 89.977, 'end': 90.097, 'score': 0.888},
#    {'word': 'have', 'start': 90.117, 'end': 90.297, 'score': 0.811},
#    {'word': 'for', 'start': 90.317, 'end': 90.437, 'score': 0.766},
#    {'word': 'free.', 'start': 90.477, 'end': 90.737, 'score': 0.827}]},
#  {'start': 90.877,
#   'end': 93.539,
#   'text': 'All you have to do is subscribe to the channel and continue watching.',
#   'words': [{'word': 'All', 'start': 90.877, 'end': 90.977, 'score': 0.998},
#    {'word': 'you', 'start': 90.997, 'end': 91.097, 'score': 0.768},
#    {'word': 'have', 'start': 91.118, 'end': 91.198, 'score': 0.996},
#    {'word': 'to', 'start': 91.218, 'end': 91.278, 'score': 0.747},
#    {'word': 'do', 'start': 91.318, 'end': 91.398, 'score': 0.796},
#    {'word': 'is', 'start': 91.438, 'end': 91.478, 'score': 0.99},
#    {'word': 'subscribe', 'start': 91.518, 'end': 91.858, 'score': 0.815},
#    {'word': 'to', 'start': 91.878, 'end': 91.918, 'score': 0.809},
#    {'word': 'the', 'start': 91.958, 'end': 92.018, 'score': 0.994},
#    {'word': 'channel', 'start': 92.038, 'end': 92.398, 'score': 0.773},
#    {'word': 'and', 'start': 92.618, 'end': 92.738, 'score': 0.657},
#    {'word': 'continue', 'start': 92.798, 'end': 93.159, 'score': 0.81},
#    {'word': 'watching.', 'start': 93.199, 'end': 93.539, 'score': 0.828}]},
#  {'start': 93.619,
#   'end': 96.2,
#   'text': 'Idea number one is an agent that controls your smart home.',
#   'words': [{'word': 'Idea', 'start': 93.619, 'end': 93.859, 'score': 0.544},
#    {'word': 'number', 'start': 93.879, 'end': 94.079, 'score': 0.906},
#    {'word': 'one', 'start': 94.239, 'end': 94.379, 'score': 0.544},
#    {'word': 'is', 'start': 94.499, 'end': 94.579, 'score': 0.699},
#    {'word': 'an', 'start': 94.599, 'end': 94.639, 'score': 0.988},
#    {'word': 'agent', 'start': 94.759, 'end': 94.979, 'score': 0.857},
#    {'word': 'that', 'start': 95.019, 'end': 95.16, 'score': 0.85},
#    {'word': 'controls', 'start': 95.2, 'end': 95.56, 'score': 0.783},
#    {'word': 'your', 'start': 95.58, 'end': 95.72, 'score': 0.837},
#    {'word': 'smart', 'start': 95.74, 'end': 95.96, 'score': 0.896},
#    {'word': 'home.', 'start': 96.0, 'end': 96.2, 'score': 0.713}]},
#  {'start': 96.32,
#   'end': 101.623,
#   'text': 'You give it access to all your cameras so it can do things like automatically turn on the heated floors when you get out of the shower.',
#   'words': [{'word': 'You', 'start': 96.32, 'end': 96.44, 'score': 0.835},
#    {'word': 'give', 'start': 96.46, 'end': 96.56, 'score': 0.888},
#    {'word': 'it', 'start': 96.58, 'end': 96.64, 'score': 0.232},
#    {'word': 'access', 'start': 96.78, 'end': 97.081, 'score': 0.942},
#    {'word': 'to', 'start': 97.121, 'end': 97.181, 'score': 0.75},
#    {'word': 'all', 'start': 97.201, 'end': 97.321, 'score': 0.807},
#    {'word': 'your', 'start': 97.361, 'end': 97.481, 'score': 0.771},
#    {'word': 'cameras', 'start': 97.501, 'end': 97.961, 'score': 0.878},
#    {'word': 'so', 'start': 98.021, 'end': 98.161, 'score': 0.378},
#    {'word': 'it', 'start': 98.181, 'end': 98.221, 'score': 0.996},
#    {'word': 'can', 'start': 98.241, 'end': 98.341, 'score': 0.997},
#    {'word': 'do', 'start': 98.381, 'end': 98.501, 'score': 0.832},
#    {'word': 'things', 'start': 98.561, 'end': 98.801, 'score': 0.806},
#    {'word': 'like', 'start': 98.861, 'end': 99.021, 'score': 0.871},
#    {'word': 'automatically', 'start': 99.102, 'end': 99.602, 'score': 0.858},
#    {'word': 'turn', 'start': 99.642, 'end': 99.822, 'score': 0.896},
#    {'word': 'on', 'start': 99.842, 'end': 99.902, 'score': 0.936},
#    {'word': 'the', 'start': 99.922, 'end': 99.982, 'score': 0.989},
#    {'word': 'heated', 'start': 100.022, 'end': 100.262, 'score': 0.783},
#    {'word': 'floors', 'start': 100.322, 'end': 100.602, 'score': 0.837},
#    {'word': 'when', 'start': 100.642, 'end': 100.742, 'score': 0.877},
#    {'word': 'you', 'start': 100.762, 'end': 100.842, 'score': 0.885},
#    {'word': 'get', 'start': 100.862, 'end': 100.962, 'score': 0.797},
#    {'word': 'out', 'start': 101.002, 'end': 101.083, 'score': 0.974},
#    {'word': 'of', 'start': 101.123, 'end': 101.163, 'score': 0.986},
#    {'word': 'the', 'start': 101.183, 'end': 101.263, 'score': 0.802},
#    {'word': 'shower.', 'start': 101.283, 'end': 101.623, 'score': 0.864}]},
#  {'start': 101.783,
#   'end': 103.924,
#   'text': 'Idea number two is to build a stockbroker agent.',
#   'words': [{'word': 'Idea', 'start': 101.783, 'end': 102.003, 'score': 0.4},
#    {'word': 'number', 'start': 102.023, 'end': 102.203, 'score': 0.991},
#    {'word': 'two', 'start': 102.243, 'end': 102.443, 'score': 0.866},
#    {'word': 'is', 'start': 102.503, 'end': 102.563, 'score': 0.781},
#    {'word': 'to', 'start': 102.603, 'end': 102.663, 'score': 0.855},
#    {'word': 'build', 'start': 102.703, 'end': 102.883, 'score': 0.743},
#    {'word': 'a', 'start': 102.943, 'end': 103.024, 'score': 0.75},
#    {'word': 'stockbroker', 'start': 103.084, 'end': 103.644, 'score': 0.879},
#    {'word': 'agent.', 'start': 103.704, 'end': 103.924, 'score': 0.891}]},
#  {'start': 103.984,
#   'end': 109.787,
#   'text': "It provides investment advice and can be used to automatically gamble your user's money when hooked up to APIs like Alpaca.",
#   'words': [{'word': 'It', 'start': 103.984, 'end': 104.044, 'score': 0.926},
#    {'word': 'provides', 'start': 104.064, 'end': 104.384, 'score': 0.766},
#    {'word': 'investment', 'start': 104.424, 'end': 104.824, 'score': 0.837},
#    {'word': 'advice', 'start': 104.844, 'end': 105.225, 'score': 0.834},
#    {'word': 'and', 'start': 105.425, 'end': 105.505, 'score': 0.842},
#    {'word': 'can', 'start': 105.525, 'end': 105.645, 'score': 0.727},
#    {'word': 'be', 'start': 105.665, 'end': 105.765, 'score': 0.818},
#    {'word': 'used', 'start': 105.845, 'end': 105.965, 'score': 0.882},
#    {'word': 'to', 'start': 105.985, 'end': 106.105, 'score': 0.914},
#    {'word': 'automatically', 'start': 106.205, 'end': 106.685, 'score': 0.86},
#    {'word': 'gamble', 'start': 106.705, 'end': 107.006, 'score': 0.865},
#    {'word': 'your', 'start': 107.026, 'end': 107.166, 'score': 0.913},
#    {'word': "user's", 'start': 107.246, 'end': 107.506, 'score': 0.708},
#    {'word': 'money', 'start': 107.546, 'end': 107.786, 'score': 0.725},
#    {'word': 'when', 'start': 107.866, 'end': 107.966, 'score': 0.99},
#    {'word': 'hooked', 'start': 107.986, 'end': 108.186, 'score': 0.899},
#    {'word': 'up', 'start': 108.266, 'end': 108.346, 'score': 0.826},
#    {'word': 'to', 'start': 108.386, 'end': 108.526, 'score': 0.766},
#    {'word': 'APIs', 'start': 108.586, 'end': 109.067, 'score': 0.71},
#    {'word': 'like', 'start': 109.107, 'end': 109.227, 'score': 0.878},
#    {'word': 'Alpaca.', 'start': 109.307, 'end': 109.787, 'score': 0.922}]},
#  {'start': 109.907,
#   'end': 115.91,
#   'text': 'Idea number three is to create an AI personal trainer that gets you in shape by calling you a fat f*** every day until you get skinny.',
#   'words': [{'word': 'Idea', 'start': 109.907, 'end': 110.107, 'score': 0.62},
#    {'word': 'number', 'start': 110.147, 'end': 110.327, 'score': 0.861},
#    {'word': 'three', 'start': 110.367, 'end': 110.627, 'score': 0.791},
#    {'word': 'is', 'start': 110.647, 'end': 110.867, 'score': 0.478},
#    {'word': 'to', 'start': 110.887, 'end': 110.968, 'score': 0.71},
#    {'word': 'create', 'start': 111.008, 'end': 111.208, 'score': 0.892},
#    {'word': 'an', 'start': 111.248, 'end': 111.308, 'score': 0.6},
#    {'word': 'AI', 'start': 111.408, 'end': 111.688, 'score': 0.824},
#    {'word': 'personal', 'start': 111.728, 'end': 112.048, 'score': 0.786},
#    {'word': 'trainer', 'start': 112.108, 'end': 112.468, 'score': 0.852},
#    {'word': 'that', 'start': 112.568, 'end': 112.708, 'score': 0.749},
#    {'word': 'gets', 'start': 112.748, 'end': 112.888, 'score': 0.973},
#    {'word': 'you', 'start': 112.928, 'end': 113.029, 'score': 0.889},
#    {'word': 'in', 'start': 113.049, 'end': 113.129, 'score': 0.67},
#    {'word': 'shape', 'start': 113.189, 'end': 113.449, 'score': 0.933},
#    {'word': 'by', 'start': 113.509, 'end': 113.609, 'score': 0.92},
#    {'word': 'calling', 'start': 113.649, 'end': 113.889, 'score': 0.865},
#    {'word': 'you', 'start': 113.929, 'end': 114.009, 'score': 0.917},
#    {'word': 'a', 'start': 114.049, 'end': 114.089, 'score': 0.52},
#    {'word': 'fat', 'start': 114.129, 'end': 114.329, 'score': 0.885},
#    {'word': 'f***', 'start': 114.449, 'end': 114.589, 'score': 0.635},
#    {'word': 'every', 'start': 114.629, 'end': 114.809, 'score': 0.892},
#    {'word': 'day', 'start': 114.829, 'end': 115.01, 'score': 0.661},
#    {'word': 'until', 'start': 115.05, 'end': 115.29, 'score': 0.83},
#    {'word': 'you', 'start': 115.33, 'end': 115.43, 'score': 0.892},
#    {'word': 'get', 'start': 115.47, 'end': 115.59, 'score': 0.926},
#    {'word': 'skinny.', 'start': 115.63, 'end': 115.91, 'score': 0.865}]},
#  {'start': 116.11,
#   'end': 119.813,
#   'text': ' Okay, those ideas sounded pretty dumb now that I say them out loud, so unsubscribe, I guess.',
#   'words': [{'word': 'Okay,', 'start': 116.11, 'end': 116.29, 'score': 0.562},
#    {'word': 'those', 'start': 116.33, 'end': 116.51, 'score': 0.621},
#    {'word': 'ideas', 'start': 116.55, 'end': 116.791, 'score': 0.9},
#    {'word': 'sounded', 'start': 116.811, 'end': 117.051, 'score': 0.872},
#    {'word': 'pretty', 'start': 117.071, 'end': 117.251, 'score': 0.99},
#    {'word': 'dumb', 'start': 117.291, 'end': 117.491, 'score': 0.786},
#    {'word': 'now', 'start': 117.511, 'end': 117.591, 'score': 0.918},
#    {'word': 'that', 'start': 117.631, 'end': 117.751, 'score': 0.765},
#    {'word': 'I', 'start': 117.771, 'end': 117.811, 'score': 0.521},
#    {'word': 'say', 'start': 117.851, 'end': 117.951, 'score': 0.927},
#    {'word': 'them', 'start': 117.971, 'end': 118.071, 'score': 0.86},
#    {'word': 'out', 'start': 118.111, 'end': 118.212, 'score': 0.92},
#    {'word': 'loud,', 'start': 118.272, 'end': 118.572, 'score': 0.952},
#    {'word': 'so', 'start': 118.612, 'end': 118.832, 'score': 0.692},
#    {'word': 'unsubscribe,', 'start': 118.932, 'end': 119.452, 'score': 0.817},
#    {'word': 'I', 'start': 119.512, 'end': 119.532, 'score': 0.756},
#    {'word': 'guess.', 'start': 119.572, 'end': 119.813, 'score': 0.65}]},
#  {'start': 119.873,
#   'end': 127.138,
#   'text': 'But to be brutally honest, the best idea is to just go out and find the trendiest AI SaaS products, steal their ideas, and put them on the GPT store as your own.',
#   'words': [{'word': 'But', 'start': 119.873, 'end': 119.993, 'score': 0.841},
#    {'word': 'to', 'start': 120.033, 'end': 120.093, 'score': 0.748},
#    {'word': 'be', 'start': 120.113, 'end': 120.213, 'score': 0.696},
#    {'word': 'brutally', 'start': 120.253, 'end': 120.593, 'score': 0.802},
#    {'word': 'honest,', 'start': 120.633, 'end': 120.973, 'score': 0.836},
#    {'word': 'the', 'start': 121.013, 'end': 121.094, 'score': 0.979},
#    {'word': 'best', 'start': 121.134, 'end': 121.314, 'score': 0.908},
#    {'word': 'idea', 'start': 121.394, 'end': 121.674, 'score': 0.864},
#    {'word': 'is', 'start': 121.754, 'end': 121.814, 'score': 0.754},
#    {'word': 'to', 'start': 121.854, 'end': 121.914, 'score': 0.968},
#    {'word': 'just', 'start': 121.954, 'end': 122.114, 'score': 0.871},
#    {'word': 'go', 'start': 122.134, 'end': 122.254, 'score': 0.918},
#    {'word': 'out', 'start': 122.314, 'end': 122.414, 'score': 0.881},
#    {'word': 'and', 'start': 122.454, 'end': 122.535, 'score': 0.827},
#    {'word': 'find', 'start': 122.575, 'end': 122.755, 'score': 0.777},
#    {'word': 'the', 'start': 122.795, 'end': 122.855, 'score': 0.994},
#    {'word': 'trendiest', 'start': 122.895, 'end': 123.375, 'score': 0.882},
#    {'word': 'AI', 'start': 123.455, 'end': 123.695, 'score': 0.824},
#    {'word': 'SaaS', 'start': 123.715, 'end': 124.016, 'score': 0.829},
#    {'word': 'products,', 'start': 124.036, 'end': 124.476, 'score': 0.826},
#    {'word': 'steal', 'start': 124.516, 'end': 124.816, 'score': 0.79},
#    {'word': 'their', 'start': 124.836, 'end': 124.976, 'score': 0.895},
#    {'word': 'ideas,', 'start': 125.036, 'end': 125.356, 'score': 0.869},
#    {'word': 'and', 'start': 125.457, 'end': 125.577, 'score': 0.696},
#    {'word': 'put', 'start': 125.597, 'end': 125.717, 'score': 0.813},
#    {'word': 'them', 'start': 125.737, 'end': 125.837, 'score': 0.89},
#    {'word': 'on', 'start': 125.877, 'end': 125.937, 'score': 0.848},
#    {'word': 'the', 'start': 125.957, 'end': 126.017, 'score': 0.983},
#    {'word': 'GPT', 'start': 126.057, 'end': 126.457, 'score': 0.785},
#    {'word': 'store', 'start': 126.477, 'end': 126.697, 'score': 0.818},
#    {'word': 'as', 'start': 126.737, 'end': 126.797, 'score': 0.733},
#    {'word': 'your', 'start': 126.817, 'end': 126.978, 'score': 0.825},
#    {'word': 'own.', 'start': 127.038, 'end': 127.138, 'score': 0.723}]},
#  {'start': 127.198,
#   'end': 132.521,
#   'text': "But what I'm building is an AI agent for my open-source spellfire library that can remotely execute code.",
#   'words': [{'word': 'But', 'start': 127.198, 'end': 127.278, 'score': 0.999},
#    {'word': 'what', 'start': 127.318, 'end': 127.418, 'score': 0.97},
#    {'word': "I'm", 'start': 127.458, 'end': 127.558, 'score': 0.927},
#    {'word': 'building', 'start': 127.598, 'end': 127.918, 'score': 0.815},
#    {'word': 'is', 'start': 128.018, 'end': 128.098, 'score': 0.874},
#    {'word': 'an', 'start': 128.118, 'end': 128.178, 'score': 0.095},
#    {'word': 'AI', 'start': 128.258, 'end': 128.479, 'score': 0.83},
#    {'word': 'agent', 'start': 128.579, 'end': 128.859, 'score': 0.826},
#    {'word': 'for', 'start': 128.899, 'end': 129.039, 'score': 0.931},
#    {'word': 'my', 'start': 129.079, 'end': 129.219, 'score': 0.872},
#    {'word': 'open-source', 'start': 129.319, 'end': 129.84, 'score': 0.838},
#    {'word': 'spellfire', 'start': 129.86, 'end': 130.3, 'score': 0.825},
#    {'word': 'library', 'start': 130.34, 'end': 130.76, 'score': 0.813},
#    {'word': 'that', 'start': 130.92, 'end': 131.08, 'score': 0.948},
#    {'word': 'can', 'start': 131.12, 'end': 131.26, 'score': 0.888},
#    {'word': 'remotely', 'start': 131.301, 'end': 131.701, 'score': 0.836},
#    {'word': 'execute', 'start': 131.821, 'end': 132.221, 'score': 0.849},
#    {'word': 'code.', 'start': 132.281, 'end': 132.521, 'score': 0.542}]},
#  {'start': 132.541,
#   'end': 139.306,
#   'text': 'Currently, chat GPT can only execute Python, but my fire breather agent can execute JavaScript in a sandboxed environment on my server.',
#   'words': [{'word': 'Currently,',
#     'start': 132.541,
#     'end': 132.842,
#     'score': 0.567},
#    {'word': 'chat', 'start': 132.862, 'end': 133.202, 'score': 0.773},
#    {'word': 'GPT', 'start': 133.222, 'end': 133.462, 'score': 0.367},
#    {'word': 'can', 'start': 133.482, 'end': 133.602, 'score': 0.72},
#    {'word': 'only', 'start': 133.662, 'end': 133.822, 'score': 0.856},
#    {'word': 'execute', 'start': 133.902, 'end': 134.263, 'score': 0.813},
#    {'word': 'Python,', 'start': 134.283, 'end': 134.763, 'score': 0.937},
#    {'word': 'but', 'start': 134.843, 'end': 134.963, 'score': 0.859},
#    {'word': 'my', 'start': 135.023, 'end': 135.163, 'score': 0.914},
#    {'word': 'fire', 'start': 135.223, 'end': 135.483, 'score': 0.89},
#    {'word': 'breather', 'start': 135.503, 'end': 135.824, 'score': 0.834},
#    {'word': 'agent', 'start': 135.864, 'end': 136.164, 'score': 0.901},
#    {'word': 'can', 'start': 136.204, 'end': 136.304, 'score': 0.987},
#    {'word': 'execute', 'start': 136.404, 'end': 136.764, 'score': 0.886},
#    {'word': 'JavaScript', 'start': 136.804, 'end': 137.385, 'score': 0.778},
#    {'word': 'in', 'start': 137.445, 'end': 137.525, 'score': 0.826},
#    {'word': 'a', 'start': 137.545, 'end': 137.605, 'score': 0.603},
#    {'word': 'sandboxed', 'start': 137.685, 'end': 138.205, 'score': 0.923},
#    {'word': 'environment', 'start': 138.245, 'end': 138.746, 'score': 0.902},
#    {'word': 'on', 'start': 138.786, 'end': 138.866, 'score': 0.863},
#    {'word': 'my', 'start': 138.906, 'end': 139.006, 'score': 0.998},
#    {'word': 'server.', 'start': 139.046, 'end': 139.306, 'score': 0.917}]},
#  {'start': 139.386,
#   'end': 143.928,
#   'text': ' This magic is made possible thanks to ChatGPT actions, formerly known as plugins.',
#   'words': [{'word': 'This', 'start': 139.386, 'end': 139.526, 'score': 0.799},
#    {'word': 'magic', 'start': 139.606, 'end': 139.866, 'score': 0.983},
#    {'word': 'is', 'start': 139.906, 'end': 139.986, 'score': 0.506},
#    {'word': 'made', 'start': 140.006, 'end': 140.146, 'score': 0.764},
#    {'word': 'possible', 'start': 140.186, 'end': 140.647, 'score': 0.832},
#    {'word': 'thanks', 'start': 140.727, 'end': 140.967, 'score': 0.809},
#    {'word': 'to', 'start': 141.007, 'end': 141.167, 'score': 0.971},
#    {'word': 'ChatGPT', 'start': 141.227, 'end': 141.947, 'score': 0.798},
#    {'word': 'actions,', 'start': 142.087, 'end': 142.428, 'score': 0.741},
#    {'word': 'formerly', 'start': 142.568, 'end': 142.968, 'score': 0.916},
#    {'word': 'known', 'start': 143.008, 'end': 143.228, 'score': 0.753},
#    {'word': 'as', 'start': 143.348, 'end': 143.448, 'score': 0.865},
#    {'word': 'plugins.', 'start': 143.508, 'end': 143.928, 'score': 0.815}]},
#  {'start': 144.008,
#   'end': 148.831,
#   'text': "You'll notice down here at the bottom on the configuration that we have an action that points to my URL.",
#   'words': [{'word': "You'll",
#     'start': 144.008,
#     'end': 144.168,
#     'score': 0.942},
#    {'word': 'notice', 'start': 144.188, 'end': 144.389, 'score': 0.795},
#    {'word': 'down', 'start': 144.409, 'end': 144.569, 'score': 0.867},
#    {'word': 'here', 'start': 144.589, 'end': 144.709, 'score': 0.784},
#    {'word': 'at', 'start': 144.729, 'end': 144.789, 'score': 0.746},
#    {'word': 'the', 'start': 144.809, 'end': 144.889, 'score': 0.836},
#    {'word': 'bottom', 'start': 144.929, 'end': 145.149, 'score': 0.964},
#    {'word': 'on', 'start': 145.189, 'end': 145.249, 'score': 0.787},
#    {'word': 'the', 'start': 145.269, 'end': 145.329, 'score': 0.988},
#    {'word': 'configuration', 'start': 145.369, 'end': 146.129, 'score': 0.883},
#    {'word': 'that', 'start': 146.289, 'end': 146.39, 'score': 0.973},
#    {'word': 'we', 'start': 146.41, 'end': 146.51, 'score': 0.832},
#    {'word': 'have', 'start': 146.55, 'end': 146.69, 'score': 0.731},
#    {'word': 'an', 'start': 146.71, 'end': 146.75, 'score': 0.964},
#    {'word': 'action', 'start': 146.95, 'end': 147.29, 'score': 0.786},
#    {'word': 'that', 'start': 147.53, 'end': 147.67, 'score': 0.924},
#    {'word': 'points', 'start': 147.75, 'end': 148.01, 'score': 0.79},
#    {'word': 'to', 'start': 148.05, 'end': 148.13, 'score': 0.983},
#    {'word': 'my', 'start': 148.15, 'end': 148.29, 'score': 0.952},
#    {'word': 'URL.', 'start': 148.391, 'end': 148.831, 'score': 0.687}]},
#  {'start': 149.011,
#   'end': 155.614,
#   'text': 'This allows ChatGPT to access an API that I built that contains the secret sauce for anything the end user would want to pay for.',
#   'words': [{'word': 'This', 'start': 149.011, 'end': 149.151, 'score': 0.812},
#    {'word': 'allows', 'start': 149.191, 'end': 149.431, 'score': 0.933},
#    {'word': 'ChatGPT', 'start': 149.491, 'end': 150.211, 'score': 0.796},
#    {'word': 'to', 'start': 150.271, 'end': 150.391, 'score': 0.998},
#    {'word': 'access', 'start': 150.572, 'end': 150.872, 'score': 0.811},
#    {'word': 'an', 'start': 150.912, 'end': 150.972, 'score': 0.541},
#    {'word': 'API', 'start': 151.072, 'end': 151.452, 'score': 0.736},
#    {'word': 'that', 'start': 151.472, 'end': 151.572, 'score': 0.99},
#    {'word': 'I', 'start': 151.612, 'end': 151.692, 'score': 0.982},
#    {'word': 'built', 'start': 151.712, 'end': 151.992, 'score': 0.575},
# ...
#    {'word': 'that', 'start': 182.092, 'end': 182.212, 'score': 0.899},
#    {'word': 'actually', 'start': 182.252, 'end': 182.573, 'score': 0.732},
#    {'word': 'does', 'start': 182.613, 'end': 182.773, 'score': 0.71},
#    {'word': 'something', 'start': 182.793, 'end': 183.053, 'score': 0.884},
#    {'word': 'useful.', 'start': 183.153, 'end': 183.433, 'score': 0.812}]},
#  {'start': 183.493,
#   'end': 189.518,
#   'text': "That's beyond the scope of this video, but basically you're going to have some input data like the information provided by the user and the chat.",
#   'words': [{'word': "That's",
#     'start': 183.493,
#     'end': 183.674,
#     'score': 0.81},
#    {'word': 'beyond', 'start': 183.714, 'end': 183.914, 'score': 0.931},
#    {'word': 'the', 'start': 183.934, 'end': 184.014, 'score': 0.836},
#    {'word': 'scope', 'start': 184.034, 'end': 184.214, 'score': 0.901},
#    {'word': 'of', 'start': 184.254, 'end': 184.294, 'score': 0.998},
#    {'word': 'this', 'start': 184.334, 'end': 184.454, 'score': 0.863},
#    {'word': 'video,', 'start': 184.474, 'end': 184.895, 'score': 0.838},
#    {'word': 'but', 'start': 184.975, 'end': 185.095, 'score': 0.835},
#    {'word': 'basically', 'start': 185.115, 'end': 185.535, 'score': 0.751},
#    {'word': "you're", 'start': 185.555, 'end': 185.695, 'score': 0.942},
#    {'word': 'going', 'start': 185.715, 'end': 185.855, 'score': 0.804},
#    {'word': 'to', 'start': 185.875, 'end': 185.935, 'score': 0.749},
#    {'word': 'have', 'start': 185.975, 'end': 186.136, 'score': 0.796},
#    {'word': 'some', 'start': 186.196, 'end': 186.336, 'score': 0.802},
#    {'word': 'input', 'start': 186.456, 'end': 186.736, 'score': 0.905},
#    {'word': 'data', 'start': 186.756, 'end': 187.096, 'score': 0.947},
#    {'word': 'like', 'start': 187.237, 'end': 187.417, 'score': 0.702},
#    {'word': 'the', 'start': 187.437, 'end': 187.517, 'score': 0.884},
#    {'word': 'information', 'start': 187.577, 'end': 188.077, 'score': 0.891},
#    {'word': 'provided', 'start': 188.117, 'end': 188.438, 'score': 0.908},
#    {'word': 'by', 'start': 188.478, 'end': 188.578, 'score': 0.798},
#    {'word': 'the', 'start': 188.618, 'end': 188.698, 'score': 0.833},
#    {'word': 'user', 'start': 188.778, 'end': 188.998, 'score': 0.736},
#    {'word': 'and', 'start': 189.018, 'end': 189.098, 'score': 0.495},
#    {'word': 'the', 'start': 189.118, 'end': 189.178, 'score': 0.996},
#    {'word': 'chat.', 'start': 189.198, 'end': 189.518, 'score': 0.876}]},
#  {'start': 189.599,
#   'end': 194.803,
#   'text': "You'll take that information and do something useful on your server, then send a response that will go back to the user and the chat.",
#   'words': [{'word': "You'll",
#     'start': 189.599,
#     'end': 189.759,
#     'score': 0.911},
#    {'word': 'take', 'start': 189.799, 'end': 189.899, 'score': 0.896},
#    {'word': 'that', 'start': 189.939, 'end': 190.039, 'score': 0.914},
#    {'word': 'information', 'start': 190.079, 'end': 190.519, 'score': 0.914},
#    {'word': 'and', 'start': 190.559, 'end': 190.639, 'score': 0.839},
#    {'word': 'do', 'start': 190.659, 'end': 190.78, 'score': 0.862},
#    {'word': 'something', 'start': 190.82, 'end': 191.08, 'score': 0.801},
#    {'word': 'useful', 'start': 191.18, 'end': 191.42, 'score': 0.848},
#    {'word': 'on', 'start': 191.48, 'end': 191.54, 'score': 0.95},
#    {'word': 'your', 'start': 191.56, 'end': 191.68, 'score': 0.828},
#    {'word': 'server,', 'start': 191.72, 'end': 192.061, 'score': 0.829},
#    {'word': 'then', 'start': 192.361, 'end': 192.521, 'score': 0.961},
#    {'word': 'send', 'start': 192.541, 'end': 192.701, 'score': 0.912},
#    {'word': 'a', 'start': 192.721, 'end': 192.781, 'score': 0.457},
#    {'word': 'response', 'start': 192.821, 'end': 193.242, 'score': 0.918},
#    {'word': 'that', 'start': 193.262, 'end': 193.362, 'score': 0.888},
#    {'word': 'will', 'start': 193.382, 'end': 193.502, 'score': 0.863},
#    {'word': 'go', 'start': 193.542, 'end': 193.622, 'score': 0.932},
#    {'word': 'back', 'start': 193.662, 'end': 193.862, 'score': 0.7},
#    {'word': 'to', 'start': 193.882, 'end': 193.962, 'score': 0.575},
#    {'word': 'the', 'start': 194.002, 'end': 194.062, 'score': 0.997},
#    {'word': 'user', 'start': 194.162, 'end': 194.363, 'score': 0.76},
#    {'word': 'and', 'start': 194.383, 'end': 194.463, 'score': 0.488},
#    {'word': 'the', 'start': 194.483, 'end': 194.543, 'score': 0.996},
#    {'word': 'chat.', 'start': 194.563, 'end': 194.803, 'score': 0.591}]},
#  {'start': 194.963,
#   'end': 206.849,
#   'text': " Now, what's crucial is that GPT understands this API, and it does that with the open API spec, which is a standard format, either in YAML or JSON, that provides a consistent structure for documenting restful APIs.",
#   'words': [{'word': 'Now,', 'start': 194.963, 'end': 195.063, 'score': 0.845},
#    {'word': "what's", 'start': 195.083, 'end': 195.223, 'score': 0.478},
#    {'word': 'crucial', 'start': 195.283, 'end': 195.683, 'score': 0.764},
#    {'word': 'is', 'start': 195.783, 'end': 195.843, 'score': 0.802},
#    {'word': 'that', 'start': 195.883, 'end': 196.004, 'score': 0.908},
#    {'word': 'GPT', 'start': 196.064, 'end': 196.624, 'score': 0.866},
#    {'word': 'understands', 'start': 196.704, 'end': 197.244, 'score': 0.854},
#    {'word': 'this', 'start': 197.284, 'end': 197.404, 'score': 0.775},
#    {'word': 'API,', 'start': 197.484, 'end': 197.965, 'score': 0.83},
#    {'word': 'and', 'start': 198.165, 'end': 198.265, 'score': 0.798},
#    {'word': 'it', 'start': 198.305, 'end': 198.345, 'score': 0.997},
#    {'word': 'does', 'start': 198.385, 'end': 198.565, 'score': 0.764},
#    {'word': 'that', 'start': 198.605, 'end': 198.805, 'score': 0.87},
#    {'word': 'with', 'start': 198.925, 'end': 199.065, 'score': 0.859},
#    {'word': 'the', 'start': 199.105, 'end': 199.205, 'score': 0.879},
#    {'word': 'open', 'start': 199.385, 'end': 199.585, 'score': 0.769},
#    {'word': 'API', 'start': 199.605, 'end': 200.066, 'score': 0.809},
#    {'word': 'spec,', 'start': 200.126, 'end': 200.446, 'score': 0.914},
#    {'word': 'which', 'start': 200.526, 'end': 200.646, 'score': 0.899},
#    {'word': 'is', 'start': 200.706, 'end': 200.766, 'score': 0.818},
#    {'word': 'a', 'start': 200.826, 'end': 200.886, 'score': 0.78},
#    {'word': 'standard', 'start': 200.966, 'end': 201.326, 'score': 0.878},
#    {'word': 'format,', 'start': 201.366, 'end': 201.766, 'score': 0.915},
#    {'word': 'either', 'start': 201.847, 'end': 202.067, 'score': 0.748},
#    {'word': 'in', 'start': 202.107, 'end': 202.187, 'score': 0.906},
#    {'word': 'YAML', 'start': 202.247, 'end': 202.587, 'score': 0.775},
#    {'word': 'or', 'start': 202.607, 'end': 202.687, 'score': 0.654},
#    {'word': 'JSON,', 'start': 202.747, 'end': 203.247, 'score': 0.911},
#    {'word': 'that', 'start': 203.307, 'end': 203.427, 'score': 0.803},
#    {'word': 'provides', 'start': 203.447, 'end': 203.787, 'score': 0.784},
#    {'word': 'a', 'start': 203.848, 'end': 203.888, 'score': 0.723},
#    {'word': 'consistent', 'start': 203.928, 'end': 204.408, 'score': 0.88},
#    {'word': 'structure', 'start': 204.448, 'end': 204.868, 'score': 0.74},
#    {'word': 'for', 'start': 204.968, 'end': 205.128, 'score': 0.696},
#    {'word': 'documenting', 'start': 205.228, 'end': 205.869, 'score': 0.914},
#    {'word': 'restful', 'start': 205.929, 'end': 206.229, 'score': 0.756},
#    {'word': 'APIs.', 'start': 206.269, 'end': 206.849, 'score': 0.742}]},
#  {'start': 206.969,
#   'end': 211.251,
#   'text': 'Now, you could generate this schema by hand, but hopefully you chose a framework that can build one automatically.',
#   'words': [{'word': 'Now,', 'start': 206.969, 'end': 207.109, 'score': 0.872},
#    {'word': 'you', 'start': 207.149, 'end': 207.229, 'score': 0.991},
#    {'word': 'could', 'start': 207.269, 'end': 207.389, 'score': 0.928},
#    {'word': 'generate', 'start': 207.409, 'end': 207.709, 'score': 0.749},
#    {'word': 'this', 'start': 207.75, 'end': 207.85, 'score': 0.674},
#    {'word': 'schema', 'start': 207.87, 'end': 208.13, 'score': 0.72},
#    {'word': 'by', 'start': 208.17, 'end': 208.29, 'score': 0.768},
#    {'word': 'hand,', 'start': 208.31, 'end': 208.67, 'score': 0.758},
#    {'word': 'but', 'start': 208.73, 'end': 208.83, 'score': 0.832},
#    {'word': 'hopefully', 'start': 208.87, 'end': 209.17, 'score': 0.959},
#    {'word': 'you', 'start': 209.19, 'end': 209.25, 'score': 0.336},
#    {'word': 'chose', 'start': 209.27, 'end': 209.45, 'score': 0.731},
#    {'word': 'a', 'start': 209.51, 'end': 209.53, 'score': 0.996},
#    {'word': 'framework', 'start': 209.55, 'end': 209.891, 'score': 0.834},
#    {'word': 'that', 'start': 209.911, 'end': 210.011, 'score': 0.872},
#    {'word': 'can', 'start': 210.031, 'end': 210.151, 'score': 0.733},
#    {'word': 'build', 'start': 210.171, 'end': 210.351, 'score': 0.763},
#    {'word': 'one', 'start': 210.431, 'end': 210.511, 'score': 0.939},
#    {'word': 'automatically.',
#     'start': 210.591,
#     'end': 211.251,
#     'score': 0.926}]},
#  {'start': 211.371,
#   'end': 217.835,
#   'text': 'In Nitro, this is experimental, which I can update here and my config, then I can either provide it as a URL or paste it here into the browser.',
#   'words': [{'word': 'In', 'start': 211.371, 'end': 211.431, 'score': 0.834},
#    {'word': 'Nitro,', 'start': 211.491, 'end': 211.792, 'score': 0.855},
#    {'word': 'this', 'start': 211.832, 'end': 211.932, 'score': 0.859},
#    {'word': 'is', 'start': 211.992, 'end': 212.052, 'score': 0.767},
#    {'word': 'experimental,', 'start': 212.112, 'end': 212.752, 'score': 0.834},
#    {'word': 'which', 'start': 212.792, 'end': 212.932, 'score': 0.818},
#    {'word': 'I', 'start': 212.972, 'end': 213.012, 'score': 0.923},
#    {'word': 'can', 'start': 213.032, 'end': 213.152, 'score': 0.809},
#    {'word': 'update', 'start': 213.252, 'end': 213.532, 'score': 0.893},
#    {'word': 'here', 'start': 213.572, 'end': 213.713, 'score': 0.945},
#    {'word': 'and', 'start': 213.733, 'end': 213.793, 'score': 0.38},
#    {'word': 'my', 'start': 213.813, 'end': 213.913, 'score': 0.68},
#    {'word': 'config,', 'start': 213.933, 'end': 214.453, 'score': 0.77},
#    {'word': 'then', 'start': 214.533, 'end': 214.653, 'score': 0.928},
#    {'word': 'I', 'start': 214.693, 'end': 214.733, 'score': 0.503},
#    {'word': 'can', 'start': 214.753, 'end': 214.853, 'score': 0.807},
#    {'word': 'either', 'start': 214.893, 'end': 215.093, 'score': 0.822},
#    {'word': 'provide', 'start': 215.133, 'end': 215.413, 'score': 0.947},
#    {'word': 'it', 'start': 215.433, 'end': 215.473, 'score': 0.852},
#    {'word': 'as', 'start': 215.553, 'end': 215.634, 'score': 0.903},
#    {'word': 'a', 'start': 215.694, 'end': 215.714, 'score': 0.903},
#    {'word': 'URL', 'start': 215.834, 'end': 216.294, 'score': 0.736},
#    {'word': 'or', 'start': 216.434, 'end': 216.514, 'score': 0.672},
#    {'word': 'paste', 'start': 216.594, 'end': 216.834, 'score': 0.883},
#    {'word': 'it', 'start': 216.874, 'end': 216.934, 'score': 0.956},
#    {'word': 'here', 'start': 216.974, 'end': 217.114, 'score': 0.882},
#    {'word': 'into', 'start': 217.154, 'end': 217.294, 'score': 0.81},
#    {'word': 'the', 'start': 217.314, 'end': 217.374, 'score': 0.994},
#    {'word': 'browser.', 'start': 217.414, 'end': 217.835, 'score': 0.82}]},
#  {'start': 218.015,
#   'end': 222.517,
#   'text': "Once that's done, all you have to do is deploy your API somewhere, then you can start testing it here in the browser.",
#   'words': [{'word': 'Once', 'start': 218.015, 'end': 218.135, 'score': 0.873},
#    {'word': "that's", 'start': 218.175, 'end': 218.395, 'score': 0.762},
#    {'word': 'done,', 'start': 218.415, 'end': 218.635, 'score': 0.712},
#    {'word': 'all', 'start': 218.735, 'end': 218.855, 'score': 0.679},
#    {'word': 'you', 'start': 218.875, 'end': 218.955, 'score': 0.97},
#    {'word': 'have', 'start': 218.995, 'end': 219.075, 'score': 0.997},
#    {'word': 'to', 'start': 219.095, 'end': 219.135, 'score': 1.0},
#    {'word': 'do', 'start': 219.155, 'end': 219.235, 'score': 0.938},
#    {'word': 'is', 'start': 219.295, 'end': 219.355, 'score': 0.752},
#    {'word': 'deploy', 'start': 219.375, 'end': 219.696, 'score': 0.803},
#    {'word': 'your', 'start': 219.716, 'end': 219.816, 'score': 0.243},
#    {'word': 'API', 'start': 219.876, 'end': 220.216, 'score': 0.788},
#    {'word': 'somewhere,', 'start': 220.256, 'end': 220.596, 'score': 0.87},
#    {'word': 'then', 'start': 220.756, 'end': 220.876, 'score': 0.878},
#    {'word': 'you', 'start': 220.896, 'end': 220.976, 'score': 0.84},
#    {'word': 'can', 'start': 220.996, 'end': 221.116, 'score': 0.871},
#    {'word': 'start', 'start': 221.136, 'end': 221.336, 'score': 0.817},
#    {'word': 'testing', 'start': 221.356, 'end': 221.697, 'score': 0.932},
#    {'word': 'it', 'start': 221.737, 'end': 221.797, 'score': 0.742},
#    {'word': 'here', 'start': 221.817, 'end': 221.957, 'score': 0.876},
#    {'word': 'in', 'start': 221.977, 'end': 222.037, 'score': 0.886},
#    {'word': 'the', 'start': 222.057, 'end': 222.117, 'score': 0.994},
#    {'word': 'browser.', 'start': 222.157, 'end': 222.517, 'score': 0.917}]},
#  {'start': 222.637,
#   'end': 228.29,
#   'text': ' Congratulations, you now have your own artificial slave agent that you can start exploiting for profit next week.',
#   'words': [{'word': 'Congratulations,',
#     'start': 222.637,
#     'end': 223.479,
#     'score': 0.833},
#    {'word': 'you', 'start': 223.579, 'end': 223.68, 'score': 0.999},
#    {'word': 'now', 'start': 223.72, 'end': 223.84, 'score': 0.784},
#    {'word': 'have', 'start': 223.86, 'end': 224.0, 'score': 0.792},
#    {'word': 'your', 'start': 224.02, 'end': 224.161, 'score': 0.679},
#    {'word': 'own', 'start': 224.241, 'end': 224.341, 'score': 0.924},
#    {'word': 'artificial', 'start': 224.461, 'end': 225.023, 'score': 0.864},
#    {'word': 'slave', 'start': 225.083, 'end': 225.604, 'score': 0.692},
#    {'word': 'agent', 'start': 225.744, 'end': 226.025, 'score': 0.888},
#    {'word': 'that', 'start': 226.065, 'end': 226.185, 'score': 0.868},
#    {'word': 'you', 'start': 226.206, 'end': 226.286, 'score': 0.835},
#    {'word': 'can', 'start': 226.306, 'end': 226.426, 'score': 0.85},
#    {'word': 'start', 'start': 226.446, 'end': 226.626, 'score': 0.743},
#    {'word': 'exploiting', 'start': 226.667, 'end': 227.088, 'score': 0.836},
#    {'word': 'for', 'start': 227.128, 'end': 227.288, 'score': 0.695},
#    {'word': 'profit', 'start': 227.388, 'end': 227.749, 'score': 0.899},
#    {'word': 'next', 'start': 227.809, 'end': 228.01, 'score': 0.73},
#    {'word': 'week.', 'start': 228.07, 'end': 228.29, 'score': 0.855}]},
#  {'start': 228.35,
#   'end': 229.393,
#   'text': 'This has been the Code Report.',
#   'words': [{'word': 'This', 'start': 228.35, 'end': 228.471, 'score': 0.984},
#    {'word': 'has', 'start': 228.491, 'end': 228.591, 'score': 0.79},
#    {'word': 'been', 'start': 228.611, 'end': 228.731, 'score': 0.917},
#    {'word': 'the', 'start': 228.771, 'end': 228.832, 'score': 0.993},
#    {'word': 'Code', 'start': 228.852, 'end': 229.012, 'score': 0.691},
#    {'word': 'Report.', 'start': 229.032, 'end': 229.393, 'score': 0.797}]},
#  {'start': 229.413,
#   'end': 232.5710625,
#   'text': 'Thanks for watching, and I will see you in the next one.',
#   'words': [{'word': 'Thanks',
#     'start': 229.413,
#     'end': 229.734,
#     'score': 0.619},
#    {'word': 'for', 'start': 229.754, 'end': 229.874, 'score': 0.856},
#    {'word': 'watching,', 'start': 229.914, 'end': 230.355, 'score': 0.87},
#    {'word': 'and', 'start': 230.515, 'end': 230.636, 'score': 0.715},
#    {'word': 'I', 'start': 230.676, 'end': 230.716, 'score': 0.638},
#    {'word': 'will', 'start': 230.736, 'end': 230.896, 'score': 0.826},
#    {'word': 'see', 'start': 230.936, 'end': 231.077, 'score': 0.777},
#    {'word': 'you', 'start': 231.097, 'end': 231.217, 'score': 0.766},
#    {'word': 'in', 'start': 231.237, 'end': 231.297, 'score': 0.256},
#    {'word': 'the', 'start': 231.317, 'end': 231.377, 'score': 0.987},
#    {'word': 'next', 'start': 231.418, 'end': 231.578, 'score': 0.804},
#    {'word': 'one.', 'start': 231.698, 'end': 231.778, 'score': 0.99}]}]

# %%
from utils.whisper_util import segments_to_srt
segments = transcription['segments']
srt = segments_to_srt(segments)
srt
# Out:
# ['1\n0:00:00:000 --> 0:00:05:000\nJust one year after launch, Chat GPT has well over 100 million daily active users.\n\n',
#  '2\n0:00:05:000 --> 0:00:11:000\nAnd next week, OpenAI is opening the floodgates, allowing developers to profit on their platform by selling custom GPT agents.\n\n',
#  "3\n0:00:11:000 --> 0:00:18:000\nAll you have to do is convince 1% of the user base to pay you $1 per month for your custom agent, and you'll be a deck of millionaire by the end of the year.\n\n",
#  "4\n0:00:18:000 --> 0:00:23:000\nBy the end of today's video, you'll know how to get rich from this once-in-a-lifetime shovelware opportunity.\n\n",
#  '5\n0:00:23:000 --> 0:00:26:000\nIt is January 5th, 2024, and you are watching the code report.\n\n',
#  '6\n0:00:26:000 --> 0:00:29:000\nBuilding a custom GPT agent is way too easy.\n\n',
#  '7\n0:00:29:000 --> 0:00:43:000\nLiterally all you do is go down to myGPTs, create a new agent, give it some custom instructions and conversation starters, and maybe upload some files with some custom data, release it on the store next week, then slap the hood and tell people how this bad boy can solve all their problems.\n\n',
#  '8\n0:00:43:000 --> 0:00:48:000\nThe barrier to entry is extremely low, and that means the GPT store will likely be filled with crapware by the end of next week.\n\n',
#  "9\n0:00:49:000 --> 0:00:55:000\nBut it may not be the only store in town for long, who incidentally screenshots for Google's bar advanced were just leaked hours ago.\n\n",
#  '10\n0:00:55:000 --> 0:00:56:000\nIt looks like barred may have its\n\n',
#  '11\n0:00:56:000 --> 0:01:00:000\nown paid tier based on Gemini Ultra in the future, along with a marketplace for developers.\n\n',
#  "12\n0:01:00:000 --> 0:01:02:000\nBut that's pure speculation at this point.\n\n",
#  '13\n0:01:02:000 --> 0:01:06:000\nNow, another big question mark is what will the revenue split be on the Chatchee BT store?\n\n',
#  '14\n0:01:06:000 --> 0:01:09:000\nWill it be $70.30 like Apple, or will it be much lower than that?\n\n',
#  '15\n0:01:09:000 --> 0:01:11:000\nBecause OpenAI is kind of doing most of the work here.\n\n',
#  "16\n0:01:11:000 --> 0:01:16:000\nIn any case, there'll be some kind of leaderboard, so if you actually create something useful, if there's a good chance you'll make a lot of money.\n\n",
#  '17\n0:01:17:000 --> 0:01:19:000\nNow the question becomes, what should I actually build?\n\n',
#  "18\n0:01:19:000 --> 0:01:26:000\nThere's already a bunch of agents built by OpenAI, like this one that will create a die cut sticker for you, and then provide a link where you can actually buy those stickers.\n\n",
#  "19\n0:01:26:000 --> 0:01:30:000\nThese are pretty cool, but luckily I have some banger ideas that I'm not going to build that you can have for free.\n\n",
#  '20\n0:01:30:000 --> 0:01:33:000\nAll you have to do is subscribe to the channel and continue watching.\n\n',
#  '21\n0:01:33:000 --> 0:01:36:000\nIdea number one is an agent that controls your smart home.\n\n',
#  '22\n0:01:36:000 --> 0:01:41:000\nYou give it access to all your cameras so it can do things like automatically turn on the heated floors when you get out of the shower.\n\n',
#  '23\n0:01:41:000 --> 0:01:43:000\nIdea number two is to build a stockbroker agent.\n\n',
#  "24\n0:01:43:000 --> 0:01:49:000\nIt provides investment advice and can be used to automatically gamble your user's money when hooked up to APIs like Alpaca.\n\n",
#  '25\n0:01:49:000 --> 0:01:55:000\nIdea number three is to create an AI personal trainer that gets you in shape by calling you a fat f*** every day until you get skinny.\n\n',
#  '26\n0:01:56:000 --> 0:01:59:000\nOkay, those ideas sounded pretty dumb now that I say them out loud, so unsubscribe, I guess.\n\n',
#  '27\n0:01:59:000 --> 0:02:07:000\nBut to be brutally honest, the best idea is to just go out and find the trendiest AI SaaS products, steal their ideas, and put them on the GPT store as your own.\n\n',
#  "28\n0:02:07:000 --> 0:02:12:000\nBut what I'm building is an AI agent for my open-source spellfire library that can remotely execute code.\n\n",
#  '29\n0:02:12:000 --> 0:02:19:000\nCurrently, chat GPT can only execute Python, but my fire breather agent can execute JavaScript in a sandboxed environment on my server.\n\n',
#  '30\n0:02:19:000 --> 0:02:23:000\nThis magic is made possible thanks to ChatGPT actions, formerly known as plugins.\n\n',
#  "31\n0:02:24:000 --> 0:02:28:000\nYou'll notice down here at the bottom on the configuration that we have an action that points to my URL.\n\n",
#  '32\n0:02:29:000 --> 0:02:35:000\nThis allows ChatGPT to access an API that I built that contains the secret sauce for anything the end user would want to pay for.\n\n',
#  '33\n0:02:35:000 --> 0:02:38:000\nThe next step is to build an actual API.\n\n',
#  "34\n0:02:38:000 --> 0:02:42:000\nThere's a million different ways to do that, but one TypeScript option I've been liking recently is Nitro.\n\n",
#  '35\n0:02:42:000 --> 0:02:45:000\nIt does file system routing and can be easily deployed almost anywhere.\n\n',
#  '36\n0:02:45:000 --> 0:02:47:000\nSo a ChatGPT action\n\n',
#  '37\n0:02:47:000 --> 0:02:51:000\nis basically just an HTTP API to that chat GPT understands.\n\n',
#  '38\n0:02:51:000 --> 0:02:57:000\nThe first step is to add an AI-plugin JSON file to the well-known directory on your website or URL.\n\n',
#  '39\n0:02:57:000 --> 0:03:00:000\nIt just provides basic information about what the API actually does.\n\n',
#  '40\n0:03:00:000 --> 0:03:03:000\nThe next step is to build an API that actually does something useful.\n\n',
#  "41\n0:03:03:000 --> 0:03:09:000\nThat's beyond the scope of this video, but basically you're going to have some input data like the information provided by the user and the chat.\n\n",
#  "42\n0:03:09:000 --> 0:03:14:000\nYou'll take that information and do something useful on your server, then send a response that will go back to the user and the chat.\n\n",
#  "43\n0:03:14:000 --> 0:03:26:000\nNow, what's crucial is that GPT understands this API, and it does that with the open API spec, which is a standard format, either in YAML or JSON, that provides a consistent structure for documenting restful APIs.\n\n",
#  '44\n0:03:26:000 --> 0:03:31:000\nNow, you could generate this schema by hand, but hopefully you chose a framework that can build one automatically.\n\n',
#  '45\n0:03:31:000 --> 0:03:37:000\nIn Nitro, this is experimental, which I can update here and my config, then I can either provide it as a URL or paste it here into the browser.\n\n',
#  "46\n0:03:38:000 --> 0:03:42:000\nOnce that's done, all you have to do is deploy your API somewhere, then you can start testing it here in the browser.\n\n",
#  '47\n0:03:42:000 --> 0:03:48:000\nCongratulations, you now have your own artificial slave agent that you can start exploiting for profit next week.\n\n',
#  '48\n0:03:48:000 --> 0:03:49:000\nThis has been the Code Report.\n\n',
#  '49\n0:03:49:000 --> 0:03:52:000\nThanks for watching, and I will see you in the next one.\n\n']
